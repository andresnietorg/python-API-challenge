# %%
# Cell 1: Dependencies and Setup

# Import necessary libraries
import matplotlib.pyplot as plt  # For plotting graphs
import pandas as pd               # For data manipulation and analysis
import numpy as np                # For numerical operations
import requests                   # For making API requests
import time                       # For adding delays (to avoid rate limiting)
from scipy.stats import linregress  # For statistical analysis (if needed)
from citipy import citipy         # For finding nearest cities based on coordinates

# Import the OpenWeatherMap API key
from api_keys import weather_api_key  # Ensure this file contains your API key
print(f"API Key: {weather_api_key}")  # Verify that the API key is loaded correctly
# Out:
# API Key: 4135a014d8ac0c6d47f53bb624cc494c

# %%
# Cell 2: Generate Cities Based on Random Latitude and Longitude

# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %%
# Cell: Retrieve Weather Data for Each City

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

print("Beginning Data Retrieval")
print("-----------------------------")
print(f"Total cities to process: {len(cities)}")

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    print(f"Attempting to retrieve weather for: {city}")

    try:
        response = requests.get(city_url, timeout=10)  # Set timeout
        
        if response.status_code == 200:
            city_weather = response.json()

            # Parse out relevant information
            city_info = {
                "City": city,
                "Temperature": city_weather['main']['temp'],
                "Humidity": city_weather['main']['humidity'],
                "Wind Speed": city_weather['wind']['speed'],
                "Description": city_weather['weather'][0]['description']
            }
            city_data.append(city_info)
        else:
            print(f"Failed to retrieve data for {city} with status code {response.status_code}: {response.text}")

    except requests.exceptions.Timeout:
        print(f"Timeout occurred while trying to retrieve data for {city}. Skipping...")
    
    except Exception as e:
        print(f"An error occurred: {e}")

    time.sleep(1)  # Pause to avoid hitting the API rate limit

# Convert collected data into a DataFrame for further analysis or visualization later on.
city_data_df = pd.DataFrame(city_data)

# Show Record Count and Display DataFrame
print("Record Count:")
print(city_data_df.count())
print(city_data_df.head())  # Display first few records of the DataFrame
# Out:
# Beginning Data Retrieval
# -----------------------------
# Total cities to process: 606
# Attempting to retrieve weather for: tual
# Attempting to retrieve weather for: waitangi
# Attempting to retrieve weather for: kalaleh
# Attempting to retrieve weather for: edinburgh of the seven seas
# Attempting to retrieve weather for: saldanha
# Attempting to retrieve weather for: moranbah
# Attempting to retrieve weather for: hawaiian paradise park
# Attempting to retrieve weather for: hamilton
# Attempting to retrieve weather for: pawni
# Attempting to retrieve weather for: long beach
# Attempting to retrieve weather for: adamstown
# Attempting to retrieve weather for: santa cruz
# Attempting to retrieve weather for: kapa'a
# Attempting to retrieve weather for: savanna-la-mar
# Attempting to retrieve weather for: kadur
# Attempting to retrieve weather for: sandnessjoen
# Attempting to retrieve weather for: bethel
# Attempting to retrieve weather for: lata
# Attempting to retrieve weather for: noyabrsk
# Attempting to retrieve weather for: alaghsas
# Attempting to retrieve weather for: isafjordur
# Attempting to retrieve weather for: siwa oasis
# Attempting to retrieve weather for: port-aux-francais
# Attempting to retrieve weather for: polyarnyy
# Attempting to retrieve weather for: margaret river
# Attempting to retrieve weather for: blackmans bay
# Attempting to retrieve weather for: selibaby
# Attempting to retrieve weather for: kendari
# Attempting to retrieve weather for: hithadhoo
# Attempting to retrieve weather for: mata-utu
# Attempting to retrieve weather for: fale old settlement
# Attempting to retrieve weather for: klyuchi
# Attempting to retrieve weather for: meadow lake
# Attempting to retrieve weather for: bredasdorp
# Attempting to retrieve weather for: invercargill
# Attempting to retrieve weather for: punta arenas
# Attempting to retrieve weather for: qasr-e qand
# Failed to retrieve data for qasr-e qand with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: ma'an
# Attempting to retrieve weather for: martapura
# Attempting to retrieve weather for: saudarkrokur
# Attempting to retrieve weather for: qaqortoq
# Attempting to retrieve weather for: anadyr
# Attempting to retrieve weather for: shetpe
# Attempting to retrieve weather for: papatowai
# Attempting to retrieve weather for: touros
# Attempting to retrieve weather for: port glaud
# Failed to retrieve data for port glaud with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: stanley
# Attempting to retrieve weather for: dudinka
# Attempting to retrieve weather for: tiksi
# Attempting to retrieve weather for: nogliki
# Attempting to retrieve weather for: bilibino
# Attempting to retrieve weather for: keflavik
# Attempting to retrieve weather for: cooma
# Attempting to retrieve weather for: thompson
# Attempting to retrieve weather for: kattivakkam
# Attempting to retrieve weather for: utrik
# Attempting to retrieve weather for: porto novo
# Attempting to retrieve weather for: mariental
# Attempting to retrieve weather for: margate
# Attempting to retrieve weather for: beshkent
# Attempting to retrieve weather for: grytviken
# Attempting to retrieve weather for: cabo san lucas
# Attempting to retrieve weather for: necocli
# Attempting to retrieve weather for: agbabu
# Attempting to retrieve weather for: taiohae
# Failed to retrieve data for taiohae with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: ushuaia
# Attempting to retrieve weather for: hermanus
# Attempting to retrieve weather for: sabang
# Attempting to retrieve weather for: picos
# Attempting to retrieve weather for: udachny
# Attempting to retrieve weather for: ribeira grande
# Attempting to retrieve weather for: bako
# Attempting to retrieve weather for: prado
# Attempting to retrieve weather for: aykhal
# Attempting to retrieve weather for: poronaysk
# Attempting to retrieve weather for: al wajh
# Attempting to retrieve weather for: nova sintra
# Attempting to retrieve weather for: vorgashor
# Attempting to retrieve weather for: hasaki
# Attempting to retrieve weather for: albany
# Attempting to retrieve weather for: puerto natales
# Attempting to retrieve weather for: college
# Attempting to retrieve weather for: st. john's
# Attempting to retrieve weather for: port lincoln
# Attempting to retrieve weather for: punta cardon
# Attempting to retrieve weather for: west island
# Attempting to retrieve weather for: coquimbo
# Attempting to retrieve weather for: ad dabbah
# Attempting to retrieve weather for: bardai
# Attempting to retrieve weather for: haapavesi
# Attempting to retrieve weather for: praia da vitoria
# Attempting to retrieve weather for: saipan
# Attempting to retrieve weather for: envira
# Attempting to retrieve weather for: daru
# Attempting to retrieve weather for: ta`u
# Attempting to retrieve weather for: camayenne
# Attempting to retrieve weather for: vila franca do campo
# Attempting to retrieve weather for: arraial do cabo
# Attempting to retrieve weather for: longyearbyen
# Attempting to retrieve weather for: port mathurin
# Attempting to retrieve weather for: boyolangu
# Attempting to retrieve weather for: port elizabeth
# Attempting to retrieve weather for: carnarvon
# Attempting to retrieve weather for: georgetown
# Attempting to retrieve weather for: minna
# Attempting to retrieve weather for: yellowknife
# Attempting to retrieve weather for: opuwo
# Attempting to retrieve weather for: iqaluit
# Attempting to retrieve weather for: murzuq
# Attempting to retrieve weather for: lihue
# Attempting to retrieve weather for: port alfred
# Attempting to retrieve weather for: mount pearl
# Attempting to retrieve weather for: san luis de la loma
# Attempting to retrieve weather for: banda aceh
# Attempting to retrieve weather for: tolanaro
# Attempting to retrieve weather for: peddapuram
# Attempting to retrieve weather for: tosontsengel
# Attempting to retrieve weather for: avarua
# Attempting to retrieve weather for: kodiak
# Attempting to retrieve weather for: kyzylorda
# Attempting to retrieve weather for: berja
# Attempting to retrieve weather for: fuvahmulah
# Failed to retrieve data for fuvahmulah with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: lagunas
# Attempting to retrieve weather for: ad dindar
# Attempting to retrieve weather for: balqash
# Attempting to retrieve weather for: alofi
# Attempting to retrieve weather for: tazovsky
# Attempting to retrieve weather for: sisophon
# Attempting to retrieve weather for: yangor
# Failed to retrieve data for yangor with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: mpongwe
# Attempting to retrieve weather for: olonkinbyen
# Attempting to retrieve weather for: puerto ayora
# Attempting to retrieve weather for: sanctuary point
# Attempting to retrieve weather for: anar darah
# Attempting to retrieve weather for: ust-nera
# Attempting to retrieve weather for: constantia
# Attempting to retrieve weather for: villa huidobro
# Attempting to retrieve weather for: chipinge
# Attempting to retrieve weather for: sanya
# Attempting to retrieve weather for: archangelos
# Attempting to retrieve weather for: oodweyne
# Attempting to retrieve weather for: sinop
# Attempting to retrieve weather for: inarajan village
# Attempting to retrieve weather for: magistral'nyy
# Attempting to retrieve weather for: saratamata
# Failed to retrieve data for saratamata with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: nuuk
# Attempting to retrieve weather for: malvik
# Attempting to retrieve weather for: taoudenni
# Attempting to retrieve weather for: betio village
# Attempting to retrieve weather for: coahuayana de hidalgo
# Attempting to retrieve weather for: cockburn town
# Attempting to retrieve weather for: petropavlovsk-kamchatsky
# Attempting to retrieve weather for: terrace
# Attempting to retrieve weather for: naze
# Attempting to retrieve weather for: grand falls-windsor
# Attempting to retrieve weather for: nookat
# Attempting to retrieve weather for: kingston
# Attempting to retrieve weather for: callao
# Attempting to retrieve weather for: enid
# Attempting to retrieve weather for: jayapura
# Attempting to retrieve weather for: mejit
# Attempting to retrieve weather for: whitehorse
# Attempting to retrieve weather for: manaure
# Attempting to retrieve weather for: zhezqazghan
# Attempting to retrieve weather for: kapuskasing
# Attempting to retrieve weather for: rongelap
# Attempting to retrieve weather for: korla
# Attempting to retrieve weather for: tsiombe
# Attempting to retrieve weather for: berwick-upon-tweed
# Attempting to retrieve weather for: cargados carajos
# Failed to retrieve data for cargados carajos with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: vilyuysk
# Attempting to retrieve weather for: tralee
# Attempting to retrieve weather for: jamestown
# Attempting to retrieve weather for: plettenberg bay
# Attempting to retrieve weather for: tofol
# Attempting to retrieve weather for: dulovo
# Attempting to retrieve weather for: kidal
# Attempting to retrieve weather for: nouadhibou
# Attempting to retrieve weather for: kashgar
# Attempting to retrieve weather for: murun-kuren
# Attempting to retrieve weather for: badger
# Attempting to retrieve weather for: soderhamn
# Attempting to retrieve weather for: talnakh
# Attempting to retrieve weather for: weno
# Attempting to retrieve weather for: afaahiti
# Attempting to retrieve weather for: barcelos
# Attempting to retrieve weather for: dzhangala
# Attempting to retrieve weather for: yaren
# Attempting to retrieve weather for: aasiaat
# Attempting to retrieve weather for: inirida
# Attempting to retrieve weather for: lebu
# Attempting to retrieve weather for: peniche
# Attempting to retrieve weather for: sitka
# Attempting to retrieve weather for: hadibu
# Attempting to retrieve weather for: trat
# Attempting to retrieve weather for: leninskoye
# Attempting to retrieve weather for: prineville
# Attempting to retrieve weather for: walvis bay
# Attempting to retrieve weather for: port-vila
# Attempting to retrieve weather for: quellon
# Attempting to retrieve weather for: beyneu
# Attempting to retrieve weather for: gamba
# Attempting to retrieve weather for: golere
# Attempting to retrieve weather for: tocopilla
# Attempting to retrieve weather for: lintong
# Attempting to retrieve weather for: monett
# Attempting to retrieve weather for: 'izbat al burj
# Failed to retrieve data for 'izbat al burj with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: zapadnaya dvina
# Attempting to retrieve weather for: flying fish cove
# Attempting to retrieve weather for: ouellah
# Failed to retrieve data for ouellah with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: kyzyl-mazhalyk
# Attempting to retrieve weather for: namibe
# Attempting to retrieve weather for: kavalerovo
# Attempting to retrieve weather for: wailua homesteads
# Attempting to retrieve weather for: katsuren-haebaru
# Attempting to retrieve weather for: ciudad lazaro cardenas
# Attempting to retrieve weather for: boa viagem
# Attempting to retrieve weather for: al hillah
# Attempting to retrieve weather for: kargasok
# Attempting to retrieve weather for: hassi messaoud
# Attempting to retrieve weather for: arpacay
# Attempting to retrieve weather for: susuman
# Attempting to retrieve weather for: serowe
# Attempting to retrieve weather for: grootfontein
# Attempting to retrieve weather for: chita
# Attempting to retrieve weather for: gaigeturi
# Attempting to retrieve weather for: kalulushi
# Attempting to retrieve weather for: uturoa
# Attempting to retrieve weather for: east ballina
# Attempting to retrieve weather for: homer
# Attempting to retrieve weather for: fort st. john
# Attempting to retrieve weather for: gunja
# Attempting to retrieve weather for: fandriana
# Attempting to retrieve weather for: minas de marcona
# Attempting to retrieve weather for: vilyuchinsk
# Attempting to retrieve weather for: emmett
# Attempting to retrieve weather for: tokar
# Attempting to retrieve weather for: tranovaho
# Failed to retrieve data for tranovaho with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: hovd
# Attempting to retrieve weather for: gadzhiyevo
# Attempting to retrieve weather for: namtsy
# Attempting to retrieve weather for: severnoye
# Attempting to retrieve weather for: saint-pierre
# Attempting to retrieve weather for: bargara
# Failed to retrieve data for bargara with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: mugia
# Attempting to retrieve weather for: san patricio
# Attempting to retrieve weather for: san juan bautista
# Attempting to retrieve weather for: gornopravdinsk
# Attempting to retrieve weather for: nar'yan-mar
# Attempting to retrieve weather for: lorengau
# Attempting to retrieve weather for: santiago de cao
# Attempting to retrieve weather for: kourou
# Attempting to retrieve weather for: siasi
# Attempting to retrieve weather for: ahau
# Failed to retrieve data for ahau with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: labytnangi
# Attempting to retrieve weather for: okeho
# Attempting to retrieve weather for: la passe
# Attempting to retrieve weather for: cole harbour
# Attempting to retrieve weather for: bethanie
# Attempting to retrieve weather for: ulladulla
# Attempting to retrieve weather for: kabo
# Attempting to retrieve weather for: nizhneangarsk
# Attempting to retrieve weather for: veraval
# Attempting to retrieve weather for: ujae
# Attempting to retrieve weather for: manthani
# Attempting to retrieve weather for: berezovyy
# Attempting to retrieve weather for: bonthe
# Attempting to retrieve weather for: scappoose
# Attempting to retrieve weather for: fort scott
# Attempting to retrieve weather for: dolores
# Attempting to retrieve weather for: luderitz
# Attempting to retrieve weather for: urangan
# Attempting to retrieve weather for: chibougamau
# Attempting to retrieve weather for: sandur
# Attempting to retrieve weather for: shibganj
# Attempting to retrieve weather for: pacasmayo
# Attempting to retrieve weather for: pudozh
# Attempting to retrieve weather for: pregradnaya
# Attempting to retrieve weather for: ad dilam
# Attempting to retrieve weather for: castillos
# Attempting to retrieve weather for: srandakan
# Attempting to retrieve weather for: diebougou
# Attempting to retrieve weather for: clarkston heights-vineland
# Attempting to retrieve weather for: inhambane
# Attempting to retrieve weather for: buala
# Attempting to retrieve weather for: makinsk
# Attempting to retrieve weather for: arno
# Attempting to retrieve weather for: new norfolk
# Attempting to retrieve weather for: luganville
# Attempting to retrieve weather for: laguna
# Attempting to retrieve weather for: ambon
# Attempting to retrieve weather for: corinto
# Attempting to retrieve weather for: ancud
# Attempting to retrieve weather for: el granada
# Attempting to retrieve weather for: bikenibeu village
# Attempting to retrieve weather for: nukunonu
# Failed to retrieve data for nukunonu with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: castelli
# Attempting to retrieve weather for: kiruna
# Attempting to retrieve weather for: isna
# Attempting to retrieve weather for: nemuro
# Attempting to retrieve weather for: sumbe
# Attempting to retrieve weather for: 'ohonua
# Failed to retrieve data for 'ohonua with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: antofagasta
# Attempting to retrieve weather for: east london
# Attempting to retrieve weather for: lethem
# Attempting to retrieve weather for: liman
# Attempting to retrieve weather for: kolonia town
# Attempting to retrieve weather for: san jose village
# Failed to retrieve data for san jose village with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: misratah
# Attempting to retrieve weather for: yatou
# Attempting to retrieve weather for: haciqabul
# Attempting to retrieve weather for: novoazovs'k
# Attempting to retrieve weather for: tshabong
# Attempting to retrieve weather for: toamasina
# Attempting to retrieve weather for: vallenar
# Attempting to retrieve weather for: cheremkhovo
# Attempting to retrieve weather for: puerto san carlos
# Failed to retrieve data for puerto san carlos with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: tulun
# Attempting to retrieve weather for: san luis
# Attempting to retrieve weather for: glace bay
# Attempting to retrieve weather for: orda
# Attempting to retrieve weather for: makar'yev
# Attempting to retrieve weather for: santana
# Attempting to retrieve weather for: pimenta bueno
# Attempting to retrieve weather for: atafu village
# Attempting to retrieve weather for: ust-tsilma
# Attempting to retrieve weather for: fortuna
# Attempting to retrieve weather for: apatity
# Attempting to retrieve weather for: kulhudhuffushi
# Attempting to retrieve weather for: hotan
# Attempting to retrieve weather for: fort bragg
# Attempting to retrieve weather for: shuangjiang
# Attempting to retrieve weather for: sinabang
# Attempting to retrieve weather for: naryn
# Attempting to retrieve weather for: nyurba
# Attempting to retrieve weather for: noumea
# Attempting to retrieve weather for: maksatikha
# Attempting to retrieve weather for: kurchatov
# Attempting to retrieve weather for: bandrele
# Attempting to retrieve weather for: lillehammer
# Attempting to retrieve weather for: zhenzhou
# Attempting to retrieve weather for: sinjai
# Attempting to retrieve weather for: warman
# Attempting to retrieve weather for: kohlu
# Attempting to retrieve weather for: hue
# Attempting to retrieve weather for: malango
# Attempting to retrieve weather for: alibag
# Attempting to retrieve weather for: gisborne
# Attempting to retrieve weather for: lompoc
# Attempting to retrieve weather for: chui
# Attempting to retrieve weather for: hualien city
# Attempting to retrieve weather for: enewetak
# Attempting to retrieve weather for: pirane
# Attempting to retrieve weather for: buford
# Attempting to retrieve weather for: gaspe
# Attempting to retrieve weather for: yuzhno-kurilsk
# Attempting to retrieve weather for: zag
# Attempting to retrieve weather for: nadym
# Attempting to retrieve weather for: nguigmi
# Attempting to retrieve weather for: bakchar
# Attempting to retrieve weather for: paka
# Attempting to retrieve weather for: bandar
# Attempting to retrieve weather for: pariaman
# Attempting to retrieve weather for: nova vicosa
# Attempting to retrieve weather for: bol'sherech'ye
# Attempting to retrieve weather for: colimes
# Attempting to retrieve weather for: laojunmiao
# Attempting to retrieve weather for: hakha
# Attempting to retrieve weather for: as sulayyil
# Attempting to retrieve weather for: howrah
# Attempting to retrieve weather for: sa kaeo
# Attempting to retrieve weather for: sakakah
# Attempting to retrieve weather for: masterton
# Attempting to retrieve weather for: mili
# Attempting to retrieve weather for: tara
# Attempting to retrieve weather for: fisterra
# Attempting to retrieve weather for: mizdah
# Attempting to retrieve weather for: nabire
# Attempting to retrieve weather for: tazacorte
# Attempting to retrieve weather for: sola
# Attempting to retrieve weather for: oriximina
# Attempting to retrieve weather for: kiunga
# Attempting to retrieve weather for: viedma
# Attempting to retrieve weather for: corumba
# Attempting to retrieve weather for: barra de santo antonio
# Attempting to retrieve weather for: ikom
# Attempting to retrieve weather for: hemsby
# Attempting to retrieve weather for: chonchi
# Attempting to retrieve weather for: mananara
# Attempting to retrieve weather for: midvagur
# Attempting to retrieve weather for: remire-montjoly
# Attempting to retrieve weather for: ungsang-nodongjagu
# Attempting to retrieve weather for: dordrecht
# Attempting to retrieve weather for: holice
# Attempting to retrieve weather for: chanasma
# Attempting to retrieve weather for: ilulissat
# Attempting to retrieve weather for: ha tinh
# Attempting to retrieve weather for: vilhena
# Attempting to retrieve weather for: klaksvik
# Attempting to retrieve weather for: tezu
# Attempting to retrieve weather for: shihezi
# Attempting to retrieve weather for: muisne
# Attempting to retrieve weather for: sterling
# Attempting to retrieve weather for: el calafate
# Attempting to retrieve weather for: wenling
# Attempting to retrieve weather for: mlowo
# Attempting to retrieve weather for: lerwick
# Attempting to retrieve weather for: gualan
# Attempting to retrieve weather for: rio preto da eva
# Attempting to retrieve weather for: newman
# Attempting to retrieve weather for: kone
# Attempting to retrieve weather for: quepos
# Attempting to retrieve weather for: kataragama
# Failed to retrieve data for kataragama with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: saint-philippe
# Attempting to retrieve weather for: kaa-khem
# Attempting to retrieve weather for: saint-francois
# Attempting to retrieve weather for: akureyri
# Attempting to retrieve weather for: port macquarie
# Attempting to retrieve weather for: dhidhdhoo
# Attempting to retrieve weather for: santa isabel
# Attempting to retrieve weather for: la'ie
# Attempting to retrieve weather for: dean funes
# Attempting to retrieve weather for: necochea
# Attempting to retrieve weather for: verkhnevilyuysk
# Attempting to retrieve weather for: biltine
# Attempting to retrieve weather for: pimentel
# Attempting to retrieve weather for: arinos
# Attempting to retrieve weather for: skutskar
# Failed to retrieve data for skutskar with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: xining
# Attempting to retrieve weather for: st. paul
# Attempting to retrieve weather for: makhambet
# Attempting to retrieve weather for: nagqu
# Attempting to retrieve weather for: port augusta
# Attempting to retrieve weather for: vyazemskiy
# Attempting to retrieve weather for: sampit
# Attempting to retrieve weather for: san fernando de apure
# Attempting to retrieve weather for: trimbak
# Attempting to retrieve weather for: ashburton
# Attempting to retrieve weather for: bay roberts
# Attempting to retrieve weather for: sarangani
# Attempting to retrieve weather for: carupano
# Attempting to retrieve weather for: balad
# Attempting to retrieve weather for: ridder
# Attempting to retrieve weather for: parnamirim
# Attempting to retrieve weather for: puerto armuelles
# Attempting to retrieve weather for: vorkuta
# Attempting to retrieve weather for: pisco
# Attempting to retrieve weather for: ad dawadimi
# Attempting to retrieve weather for: rawai
# Attempting to retrieve weather for: mount gambier
# Attempting to retrieve weather for: colonia
# Attempting to retrieve weather for: hami
# Attempting to retrieve weather for: fernie
# Attempting to retrieve weather for: devinuwara
# Failed to retrieve data for devinuwara with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: kaiapoi
# Attempting to retrieve weather for: vingt cinq
# Failed to retrieve data for vingt cinq with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: fort mcmurray
# Attempting to retrieve weather for: khandyga
# Attempting to retrieve weather for: sao paulo de olivenca
# Attempting to retrieve weather for: bayramaly
# Attempting to retrieve weather for: hastings
# Attempting to retrieve weather for: pindwara
# Attempting to retrieve weather for: iwanai
# Attempting to retrieve weather for: palikir - national government center
# Attempting to retrieve weather for: ansalta
# Attempting to retrieve weather for: konarka
# Attempting to retrieve weather for: iskushuban
# Attempting to retrieve weather for: coari
# Attempting to retrieve weather for: maracas
# Attempting to retrieve weather for: oualidia
# Failed to retrieve data for oualidia with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: karamay
# Attempting to retrieve weather for: sos'va
# Attempting to retrieve weather for: piacabucu
# Attempting to retrieve weather for: recani
# Attempting to retrieve weather for: kuanda
# Attempting to retrieve weather for: bahia de caraquez
# Attempting to retrieve weather for: turpan
# Attempting to retrieve weather for: khasab
# Attempting to retrieve weather for: novodvinsk
# Attempting to retrieve weather for: okhotsk
# Attempting to retrieve weather for: usogorsk
# Attempting to retrieve weather for: maintirano
# Attempting to retrieve weather for: saint-louis
# Attempting to retrieve weather for: hihifo
# Failed to retrieve data for hihifo with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: ressano garcia
# Attempting to retrieve weather for: lago da pedra
# Attempting to retrieve weather for: jamaame
# Attempting to retrieve weather for: fortaleza
# Attempting to retrieve weather for: flin flon
# Attempting to retrieve weather for: qarauyl
# Attempting to retrieve weather for: camiri
# Attempting to retrieve weather for: malpura
# Attempting to retrieve weather for: pasighat
# Attempting to retrieve weather for: naama
# Attempting to retrieve weather for: lodi
# Attempting to retrieve weather for: cidreira
# Attempting to retrieve weather for: sao vicente
# Attempting to retrieve weather for: fang
# Attempting to retrieve weather for: dalandzadgad
# Attempting to retrieve weather for: whitecourt
# Attempting to retrieve weather for: lijiang
# Attempting to retrieve weather for: ketchikan
# Attempting to retrieve weather for: bangassou
# Attempting to retrieve weather for: ii
# Failed to retrieve data for ii with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: tromso
# Attempting to retrieve weather for: petauke
# Attempting to retrieve weather for: nenjiang
# Attempting to retrieve weather for: san antonio de pale
# Attempting to retrieve weather for: jincheng
# Attempting to retrieve weather for: tanout
# Attempting to retrieve weather for: isangel
# Attempting to retrieve weather for: cacheu
# Attempting to retrieve weather for: mirnyy
# Attempting to retrieve weather for: bubaque
# Attempting to retrieve weather for: sisimiut
# Attempting to retrieve weather for: burley
# Attempting to retrieve weather for: nema
# Attempting to retrieve weather for: chunskiy
# Attempting to retrieve weather for: hilo
# Attempting to retrieve weather for: bom jesus da lapa
# Attempting to retrieve weather for: alotau
# Attempting to retrieve weather for: saguenay
# Attempting to retrieve weather for: howard springs
# Attempting to retrieve weather for: smithers
# Attempting to retrieve weather for: selfoss
# Attempting to retrieve weather for: rawson
# Attempting to retrieve weather for: marsaskala
# Failed to retrieve data for marsaskala with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: mahibadhoo
# Attempting to retrieve weather for: antalaha
# Attempting to retrieve weather for: priozersk
# Attempting to retrieve weather for: dehri
# Attempting to retrieve weather for: sabha
# Attempting to retrieve weather for: new plymouth
# Attempting to retrieve weather for: porto seguro
# Attempting to retrieve weather for: chernyshevskiy
# Attempting to retrieve weather for: kokstad
# Attempting to retrieve weather for: oran
# Attempting to retrieve weather for: keren
# Attempting to retrieve weather for: yokadouma
# Attempting to retrieve weather for: yangquan
# Attempting to retrieve weather for: jalalabad
# Attempting to retrieve weather for: taltal
# Attempting to retrieve weather for: otavalo
# Attempting to retrieve weather for: bairnsdale
# Attempting to retrieve weather for: shingu
# Attempting to retrieve weather for: puerto colombia
# Attempting to retrieve weather for: kaohsiung
# Attempting to retrieve weather for: yujing
# Attempting to retrieve weather for: butte
# Attempting to retrieve weather for: chul'man
# Attempting to retrieve weather for: nangong
# Attempting to retrieve weather for: jalai nur
# Attempting to retrieve weather for: manokwari
# Attempting to retrieve weather for: bich'vinta
# Attempting to retrieve weather for: atherton
# Attempting to retrieve weather for: zakamensk
# Attempting to retrieve weather for: uruguaiana
# Attempting to retrieve weather for: torghay
# Attempting to retrieve weather for: gizo
# Attempting to retrieve weather for: takamaka
# Failed to retrieve data for takamaka with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: geraldton
# Attempting to retrieve weather for: kelibia
# Attempting to retrieve weather for: vershino-darasunskiy
# Attempting to retrieve weather for: point pedro
# Attempting to retrieve weather for: severo-yeniseyskiy
# Attempting to retrieve weather for: shimoda
# Attempting to retrieve weather for: whitby
# Attempting to retrieve weather for: mulchen
# Attempting to retrieve weather for: labrador city
# Attempting to retrieve weather for: gulf shores
# Attempting to retrieve weather for: richards bay
# Attempting to retrieve weather for: hayma'
# Failed to retrieve data for hayma' with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: petukhovo
# Attempting to retrieve weather for: morant bay
# Attempting to retrieve weather for: novokazalinsk
# Failed to retrieve data for novokazalinsk with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: basco
# Attempting to retrieve weather for: rodolfo sanchez taboada
# Attempting to retrieve weather for: ijuw
# Failed to retrieve data for ijuw with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: amungan
# Attempting to retrieve weather for: vilino
# Attempting to retrieve weather for: suntar
# Attempting to retrieve weather for: candido de abreu
# Attempting to retrieve weather for: salahonda
# Attempting to retrieve weather for: sanga-sanga
# Attempting to retrieve weather for: yanbu
# Attempting to retrieve weather for: rechka-vydrino
# Attempting to retrieve weather for: shangzhi
# Attempting to retrieve weather for: mahwah
# Attempting to retrieve weather for: dwarka
# Attempting to retrieve weather for: guerrero negro
# Attempting to retrieve weather for: zheleznodorozhnyy
# Attempting to retrieve weather for: bouca
# Attempting to retrieve weather for: hoxtolgay
# Failed to retrieve data for hoxtolgay with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: alpine
# Attempting to retrieve weather for: ciudad melchor muzquiz
# Attempting to retrieve weather for: ouani
# Attempting to retrieve weather for: broome
# Attempting to retrieve weather for: madison
# Attempting to retrieve weather for: ilhabela
# Attempting to retrieve weather for: savannakhet
# Attempting to retrieve weather for: cumaribo
# Failed to retrieve data for cumaribo with status code 404: {"cod":"404","message":"city not found"}
# Attempting to retrieve weather for: carutapera
# Attempting to retrieve weather for: dondaicha
# Attempting to retrieve weather for: stiens
# Attempting to retrieve weather for: sur
# Attempting to retrieve weather for: bel ombre
# Record Count:
# City           576
# Temperature    576
# Humidity       576
# Wind Speed     576
# Description    576
# dtype: int64
#                           City  Temperature  Humidity  Wind Speed  \
# 0                         tual        28.38        73        5.47
# 1                     waitangi        12.68        89        2.68
# 2                      kalaleh        14.48        51        2.57
# 3  edinburgh of the seven seas        13.01        80        6.88
# 4                     saldanha        15.97        91        6.90
#
#         Description
# 0  scattered clouds
# 1        light rain
# 2   overcast clouds
# 3   overcast clouds
# 4     broken clouds

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
print("Data Exported successfully!")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'], marker='o', color='blue', alpha=0.5)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], marker='o', color='blue', alpha=0.5)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], marker='o', color='blue', alpha=0.5)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], marker='o', color='blue', alpha=0.5)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

def create_linear_regression_plot(x, y, x_label, y_label, title):
    """
    Create a scatter plot with a linear regression line.

    Parameters:
    x : array-like
        The independent variable (e.g., latitude).
    y : array-like
        The dependent variable (e.g., temperature, humidity).
    x_label : str
        Label for the x-axis.
    y_label : str
        Label for the y-axis.
    title : str
        Title of the plot.
    """
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    
    # Calculate regression line values
    fit_line = slope * x + intercept
    
    # Create scatter plot
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, marker='o', color='blue', alpha=0.5)
    
    # Plot the regression line
    plt.plot(x, fit_line, color='red', linewidth=2)

    # Incorporate other graph properties
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid()
    
    # Save the figure
    plt.savefig(f"output_data/{title.replace(' ', '_')}.png")
    
    # Show plot
    plt.show()

# Example usage with your DataFrame:
create_linear_regression_plot(
    city_data_df['Latitude'], 
    city_data_df['Temperature'], 
    'Latitude', 
    'Temperature (°C)', 
    'Linear Regression of Latitude vs Temperature'
)

create_linear_regression_plot(
    city_data_df['Latitude'], 
    city_data_df['Humidity'], 
    'Latitude', 
    'Humidity (%)', 
    'Linear Regression of Latitude vs Humidity'
)

create_linear_regression_plot(
    city_data_df['Latitude'], 
    city_data_df['Wind Speed'], 
    'Latitude', 
    'Wind Speed (m/s)', 
    'Linear Regression of Latitude vs Wind Speed'
)

create_linear_regression_plot(
   city_data_df['Latitude'],
   city_data_df['Cloudiness'],
   'Latitude',
   'Cloudiness (%)',
   'Linear Regression of Latitude vs Cloudiness'
)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Latitude'] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Latitude'] < 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Assuming northern_hemi_df is already created and contains 'Latitude' and 'Temperature' columns

# Perform linear regression on Northern Hemisphere data
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Latitude'], northern_hemi_df['Temperature'])

# Calculate the regression line values
fit_line = slope * northern_hemi_df['Latitude'] + intercept

# Create a scatter plot for Latitude vs Temperature
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df['Latitude'], northern_hemi_df['Temperature'], marker='o', color='blue', alpha=0.5)

# Plot the regression line
plt.plot(northern_hemi_df['Latitude'], fit_line, color='red', linewidth=2)

# Incorporate other graph properties
plt.title('Northern Hemisphere: Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Northern_Hemisphere_Latitude_vs_Temperature.png")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress



# Perform linear regression on Southern Hemisphere data
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df['Latitude'], southern_hemi_df['Temperature'])

# Calculate the regression line values
fit_line = slope * southern_hemi_df['Latitude'] + intercept

# Create a scatter plot for Latitude vs Temperature
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df['Latitude'], southern_hemi_df['Temperature'], marker='o', color='blue', alpha=0.5)

# Plot the regression line
plt.plot(southern_hemi_df['Latitude'], fit_line, color='red', linewidth=2)

# Incorporate other graph properties
plt.title('Southern Hemisphere: Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Southern_Hemisphere_Latitude_vs_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
